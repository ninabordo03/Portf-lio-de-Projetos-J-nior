# %%
import pandas as pd

# %%
h = pd.read_csv('housing.csv')
h
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
h.describe
# Out:
# <bound method NDFrame.describe of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
h.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
h.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
h = h.dropna()
h.isna().sum().any()
# Out:
# False

# %%
h.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
h['longitude'].unique()
# Out:
# array([-122.23, -122.22, -122.24, -122.25, -122.26, -122.27, -122.28,
#        -122.29, -122.3 , -122.21, -122.2 , -122.19, -122.18, -122.13,
#        -122.16, -122.17, -122.15, -122.14, -122.12, -122.33, -122.34,
#        -122.06, -122.07, -122.08, -122.09, -122.1 , -122.11, -122.03,
#        -121.97, -122.02, -122.04, -122.05, -121.99, -122.01, -121.96,
#        -121.98, -122.  , -121.93, -121.94, -121.95, -121.92, -121.89,
#        -121.91, -121.9 , -121.88, -121.87, -121.85, -121.86, -121.84,
#        -121.82, -121.77, -121.62, -121.61, -121.72, -121.73, -121.75,
#        -121.8 , -121.76, -121.78, -121.79, -119.78, -119.93, -120.  ,
#        -120.56, -120.59, -120.55, -120.25, -120.79, -120.8 , -120.65,
#        -120.76, -120.88, -120.69, -120.93, -120.97, -120.87, -120.98,
#        -120.72, -120.77, -120.66, -120.62, -120.71, -121.83, -121.81,
#        -121.74, -121.68, -121.54, -121.51, -121.59, -121.58, -121.6 ,
# ...

# %%
h['latitude'].unique()
# Out:
# array([37.88, 37.86, 37.85, 37.84, 37.83, 37.82, 37.81, 37.8 , 37.79,
#        37.77, 37.78, 37.76, 37.75, 37.74, 37.73, 37.9 , 37.89, 37.87,
#        37.72, 37.71, 37.7 , 37.69, 37.68, 37.64, 37.63, 37.66, 37.65,
#        37.67, 37.61, 37.62, 37.6 , 37.59, 37.58, 37.57, 37.49, 37.52,
#        37.56, 37.55, 37.54, 37.53, 37.51, 37.48, 37.47, 37.5 , 38.69,
#        38.72, 38.52, 38.48, 38.45, 38.46, 38.43, 38.55, 38.54, 38.51,
#        38.5 , 38.47, 38.44, 38.42, 38.37, 38.34, 38.32, 38.26, 38.38,
#        38.4 , 38.39, 38.36, 38.31, 39.76, 39.78, 39.77, 39.74, 39.75,
#        39.73, 39.71, 39.72, 39.7 , 39.82, 39.79, 39.68, 39.64, 39.59,
#        39.88, 40.06, 39.97, 39.86, 39.83, 39.8 , 39.66, 39.69, 39.61,
#        39.65, 39.55, 39.52, 39.53, 39.6 , 39.54, 39.5 , 39.49, 39.51,
#        39.48, 39.47, 39.45, 39.44, 39.43, 39.4 , 39.39, 39.33, 39.37,
#        39.35, 39.34, 39.32, 39.36, 39.38, 39.42, 39.41, 38.15, 38.12,
# ...

# %%
h['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
newocean = {'NEAR BAY': 1, '<1H OCEAN': 2, 'INLAND': 3, 'NEAR OCEAN': 4, 'ISLAND': 5}
for f in h['ocean_proximity']:
    h['ocean_proximity'] = h['ocean_proximity'].replace(newocean)
h
# Out:
# C:\Users\sidal\AppData\Local\Temp\ipykernel_13048\1413289924.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h['ocean_proximity'] = h['ocean_proximity'].replace(newocean)
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# ...

# %%
matrix = h.corr()
matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
# ocean_proximity      0.181198 -0.067980           -0.206178     0.015917
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# ...

# %%
#relação do preço com median income e ocean proximity

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import metrics
x = h.drop('median_house_value', axis = 1)
y = h['median_house_value']
from sklearn.model_selection import train_test_split
xtreino, xteste, ytreino, yteste = train_test_split(x, y, test_size=0.33, random_state=42)
lrtreino = LinearRegression().fit(xtreino, ytreino)
lrtreino
# Out:
# LinearRegression()

# %%
modelres = pd.DataFrame(columns= ['Model', 'R2Score'])

# %%
ypredtreino = lrtreino.predict(xtreino)
r2scoretreino = metrics.r2_score(ytreino, ypredtreino)
r2scoretreino
# Out:
# 0.6318746647376492

# %%
lrtreino.score(xtreino, ytreino)
# Out:
# 0.6318746647376492

# %%
lrteste = LinearRegression().fit(xteste, yteste)
lrteste.score(xteste, yteste)
# Out:
# 0.6498249208140386

# %%
ypredteste = lrteste.predict(xteste)
r2scoreteste = metrics.r2_score(yteste, ypredteste)
r2scoreteste
# Out:
# 0.6498249208140386

# %%
#XGBoost Regressor

# %%
from xgboost import XGBRegressor
xgbtreino = XGBRegressor().fit(xtreino, ytreino)
xgbtreino
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgbpredtreino = xgbtreino.predict(xtreino)

# %%
from sklearn.metrics import r2_score
from sklearn import metrics
r2scoretreinoxgb = metrics.r2_score(ytreino, xgbpredtreino)
r2scoretreinoxgb
# Out:
# 0.9451583373703962

# %%
xgbteste = XGBRegressor().fit(xteste, yteste)
xgbteste
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgbpredteste = xgbteste.predict(xteste)

# %%
r2scoretestexgb = metrics.r2_score(yteste, xgbpredteste)
r2scoretestexgb
# Out:
# 0.9686017374013475

# %%
from sklearn.metrics import mean_absolute_error
meantreino = metrics.mean_absolute_error(ytreino, xgbpredtreino)
meantreino
# Out:
# 19249.478942630343

# %%
meanteste = metrics.mean_absolute_error(yteste, xgbpredteste)
meanteste
# Out:
# 14683.680954149211

# %%
modelres.loc[len(modelres)] = ['XGBRegression Teste', r2scoretestexgb]
modelres.loc[len(modelres)] = ['XGBRegression Treino', r2scoretreinoxgb]
modelres.loc[len(modelres)] = ['Linear Regression Teste', r2scoreteste]
modelres.loc[len(modelres)] = ['Linear Regression Treino', r2scoretreino]

# %%
#visualizando as predições para od dados de treino
import matplotlib.pyplot as plt
plt.scatter(ytreino, xgbpredtreino)
plt.xlabel('Actual Prices')
plt.ylabel('Actual Price vs Predicted Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#visualizando as predições para od dados de teste
import matplotlib.pyplot as plt
plt.scatter(yteste, xgbpredteste)
plt.xlabel('Actual Prices')
plt.ylabel('Actual Price vs Predicted Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#criando uma tabela para mostrar os scores em ordem decrescente

# %%
modelres = modelres.sort_values(by='R2Score', ascending=False)
modelres
# Out:
#                       Model   R2Score
# 0       XGBRegression Teste  0.968602
# 1      XGBRegression Treino  0.945158
# 2   Linear Regression Teste  0.649825
# 3  Linear Regression Treino  0.631875
